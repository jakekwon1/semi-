# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


from matplotlib import font_manager, rc

font_path = './malgun.ttf'
font_name = font_manager.FontProperties (fname=font_path).get_name()
rc('font', family=font_name)

df1=pd.read_excel('시도_직업별_2008__이혼_20230227144800.xlsx')


df1=df1.fillna(method='pad')


df1.set_index(['시도별','직업별'],inplace=True)

df1=df1.loc['전국']
df1=df1.astype(int)

list_a=[]
for i in range(0,len(df1.columns),1):
    if i % 2 == 0:
        df1.iloc[:,i] = df1.iloc[:,i] + df1.iloc[:,i+1]
        list_a.append(i+1)
        
df1.drop(df1.columns[[list_a]],axis=1,inplace=True)
df1.drop(df1.index[[9,10]],inplace=True)


df1.rename(index={'계':'이혼자 수'},inplace=True)
df1.loc['이혼자 수'] = '이혼자 수'
df1

df2=pd.read_excel('직종별_임금_및_근로시간__표준직업분류6차__20230227144915.xlsx')

df2=df2.fillna(method='pad')

df2.set_index(['고용형태','한국표준직업분류6차'],inplace=True)
df2 = df2.loc[['고용형태','전체근로자']]

list_a =[]

for i in range(0,len(df2.columns),1):
    if len(df2.columns[i]) == 7:
        list_a.append(i)
    else : 
        if '.1' not in df2.columns[i]:
            if '.7'not in df2.columns[i]:
                list_a.append(i)
                
df2.drop(df2.columns[[list_a]],axis=1,inplace=True)
df2.iloc[1:,:].astype(float)
df2

df2.loc['전체근로자','서비스 종사자(4)']=(df2.loc['전체근로자','서비스 종사자(4)'] + df2.loc['전체근로자','판매 종사자(5)']) / 2 
df2.drop(df2.index[6],inplace=True)
df2.rename(index={'관리자(1)': '관리자',
                  '전문가 및 관련 종사자(2)':'전문가 및 관련 종사자',
                 '사무 종사자(3)':'사무 종사자',
                 '서비스 종사자(4)':'서비스 및 판매 종사자',
                 '농림어업 숙련 종사자(6)':'농림어업 숙련 종사자',
                 '기능원 및 관련 기능 종사자(7)':'기능원 및 관련 기능 종사자',
                 '장치,기계조작 및 조립종사자(8)':'장치,기계 조작 및 조립 종사자',
                 '단순노무 종사자(9)':'단순노무 종사자'}, inplace=True)


df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5069: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


from matplotlib import font_manager, rc

font_path = './malgun.ttf'
font_name = font_manager.FontProperties (fname=font_path).get_name()
rc('font', family=font_name)

df1=pd.read_excel('시도_직업별_2008__이혼_20230227144800.xlsx')


df1=df1.fillna(method='pad')


df1.set_index(['시도별','직업별'],inplace=True)

df1=df1.loc['전국']
df1=df1.astype(int)

list_a=[]
for i in range(0,len(df1.columns),1):
    if i % 2 == 0:
        df1.iloc[:,i] = df1.iloc[:,i] + df1.iloc[:,i+1]
        list_a.append(i+1)
        
df1.drop(df1.columns[[list_a]],axis=1,inplace=True)
df1.drop(df1.index[[9,10]],inplace=True)


df1.rename(index={'계':'이혼자 수'},inplace=True)
df1.loc['이혼자 수'] = '이혼자 수'
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5069: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#                     2009   2010   2011   2012   2013   2014   2015   2016  \
# 직업별
# 이혼자 수              이혼자 수  이혼자 수  이혼자 수  이혼자 수  이혼자 수  이혼자 수  이혼자 수  이혼자 수
# 관리자                 4554   4711   4317   7913   9873  10697  11098  11992
# 전문가 및 관련 종사자       17106  15904  16015  18414  21107  23056  23520  23480
# 사무 종사자             36365  35231  35366  31017  28074  25850  23428  21911
# ...
