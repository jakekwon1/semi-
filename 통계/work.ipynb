# %%
import folium
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_path = './malgun.ttf'
font_name = font_manager.FontProperties (fname=font_path).get_name()
rc('font', family=font_name)

# %%
df1=pd.read_csv('./직종별_임금_및_근로시간_2015-17.csv',encoding='cp949')
df2=pd.read_csv('./시도_직업별_2008__이혼_2015-17.csv',encoding='cp949')
#df3=pd.read_csv('./시도_직업별_2008__이혼_2015-17.csv',encoding='cp949')

# %%
df2.head(30)
# Out:
#       시도별                직업별    2015  2015.1    2016  2016.1    2017  2017.1
# 0     시도별                직업별      남편      아내      남편      아내      남편      아내
# 1      전국                  계  109153  109153  107328  107328  106032  106032
# 2      전국                관리자    8635    2463    9220    2772    9359    2907
# 3      전국       전문가 및 관련 종사자   13090   10430   12634   10846   12707   10916
# 4      전국             사무 종사자   12384   11044   11140   10771   10282   10386
# 5      전국       서비스 및 판매 종사자   22016   22960   20744   22665   19862   22038
# 6      전국        농림어업 숙련 종사자    3318     730    3249     746    3120     741
# 7      전국    기능원 및 관련 기능 종사자    8774    1853    8232    1704    7588    1779
# 8      전국  장치,기계 조작 및 조립 종사자    6116     979    6212    1061    6348     993
# 9      전국           단순노무 종사자   11135    6253   10867    6114   11483    6299
# 10     전국         무직, 가사, 학생   17809   47017   16726   42550   15599   40481
# 11     전국            기타 및 미상    5876    5424    8304    8099    9684    9492
# 12  서울특별시                  계   18176   18550   17777   18043   17083   17379
# 13  서울특별시                관리자    1486     477    1539     535    1465     519
# 14  서울특별시       전문가 및 관련 종사자    2595    2007    2289    1955    2240    2000
# 15  서울특별시             사무 종사자    2420    2199    2427    2204    1962    1872
# 16  서울특별시       서비스 및 판매 종사자    4188    3848    3529    3501    3243    3347
# 17  서울특별시        농림어업 숙련 종사자      67      36      70      22      61      25
# 18  서울특별시    기능원 및 관련 기능 종사자     884     257     802     227     715     223
# 19  서울특별시  장치,기계 조작 및 조립 종사자     432      63     410      54     384      34
# 20  서울특별시           단순노무 종사자    1335     725    1354     642    1340     639
# 21  서울특별시         무직, 가사, 학생    2883    7058    2946    6420    2666    5607
# 22  서울특별시            기타 및 미상    1886    1880    2411    2483    3007    3113
# 23  부산광역시                  계    6649    6806    6859    6962    6651    6690
# 24  부산광역시                관리자     482     132     606     132     579     174
# 25  부산광역시       전문가 및 관련 종사자     710     577     783     657     735     623
# 26  부산광역시             사무 종사자     738     569     683     570     594     512
# 27  부산광역시       서비스 및 판매 종사자    1314    1489    1198    1471    1077    1276
# 28  부산광역시        농림어업 숙련 종사자     109      14      79      14      92      21
# 29  부산광역시    기능원 및 관련 기능 종사자     666     118     515      88     429      86

# %%
df2=df2.rename(columns={'2015.1':'2015','2017.1':'2017'})
df2=df2.drop(['2015','2017'],axis=1)

# %%
a=df2[df2['시도별'].str.contains('부산광역시')]
a.set_index('시도별')
a=a.reset_index()
a=a.drop('index',axis=1)

# %%
df2['']

# %%
main=pd.DataFrame(a)

# %%
main=main.set_index('시도별')

# %%
main=main.rename(columns={'2016':'남편','2016.1':'아내'})

# %%
total=main.iloc[0]
main_d=main.iloc[1:]
main_d['아내'].astype(int)
man=main_d['남편'].astype(int)
man

#main_d.dtypes
# Out:
# 시도별
# 부산광역시     606
# 부산광역시     783
# 부산광역시     683
# 부산광역시    1198
# 부산광역시      79
# 부산광역시     515
# 부산광역시     365
# 부산광역시    1105
# 부산광역시    1192
# 부산광역시     333
# Name: 남편, dtype: int32

# %%
# data = {'A': 20, 'B': 35, 'C': 25, 'D': 20}
# labels = list(data.keys())
# values = list(data.values())

# # 원형 차트 그리기
# fig1, ax1 = plt.subplots()
# ax1.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
# ax1.axis('equal')

# # 그래프 출력
# plt.show()
# group_names = ['Group A', 'Group B']
# group_values = [40, 60]

# # 그룹 내부에서 각 항목의 이름과 값이 딕셔너리 형태로 주어짐
# subgroup_names = ['A1', 'A2', 'B1', 'B2', 'B3']
# subgroup_values = [10, 30, 20, 15, 25]

# # 색상 설정
# colors = ['lightcoral', 'lightskyblue']

# # 첫 번째 그룹에 대한 원형 차트 그리기
# fig2, ax2 = plt.subplots()
# ax2.pie(group_values, labels=group_names, colors=colors, startangle=90, autopct='%1.1f%%', radius=1)
# ax2.axis('equal')

# # 두 번째 그룹에 대한 원형 차트 그리기
# ax2.pie(subgroup_values, labels=subgroup_names, labeldistance=0.7, colors=colors, radius=0.7, autopct='%1.1f%%', startangle=90)

# # 그래프 출력
# plt.show()

# %%
fig=plt.figure(figsize=(15,5))
ax1=fig.add_subplot(1,2,2)


plt.rc('font', family='Malgun Gothic')
plt.pie
plt.pie(main_d['남편'], labels=main_d['직업별'],autopct='%0.1f%%')



plt.show()

# %%
plt.rc('font', family='Malgun Gothic')
plt.pie
plt.pie(main_d['아내'], labels=main_d['직업별'],autopct='%0.1f%%')
plt.show()

# %%
names = main_d['직업별']
group_values = main_d['아내']
subgroup_values = main_d['남편']

fig2, ax2 = plt.subplots(figsize=(25, 15))
ax2.pie(group_values, labels=names, startangle=90,colors = ['red', 'tomato', 'orange', 'crimson','yellow'],
        autopct='%1.1f%%',labeldistance=1.1, radius=1.2,textprops={'fontsize': 10})
ax2.axis('equal')
ax2.pie(subgroup_values, labels=names, labeldistance=0.3, radius=.8,colors = ['blue', 'dodgerblue', 'royalblue', 'deepskyblue'],
        autopct='%1.1f%%', startangle=90,textprops={'fontsize': 13})

#plt.text(1.4, 0.7, '원형 차트와 글', fontsize=15, ha='center', va='center')


plt.show()
