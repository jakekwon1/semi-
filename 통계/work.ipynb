# %%
import folium
import pandas as pd

# %%
df1=pd.read_csv('./직종별_임금_및_근로시간.csv',encoding='cp949')
df2=pd.read_csv('./시도_직업별_2008__이혼.csv',encoding='cp949')
df1
# Out:
#                고용형태          한국표준직업분류6차       2019      2019.1        2019.2  \
# 0              고용형태          한국표준직업분류6차  총근로일수 (일)  총근로시간 (시간)  소정실근로시간 (시간)
# 1             전체근로자                 전직종       19.2       152.4         144.9
# 2             전체근로자              관리자(1)       19.5       159.2         155.0
# 3             전체근로자     전문가 및 관련 종사자(2)       19.3       152.8         147.5
# 4             전체근로자           사무 종사자(3)       19.5       156.8         151.8
# 5             전체근로자          서비스 종사자(4)       18.8       132.5         129.1
# 6             전체근로자           판매 종사자(5)       19.1       147.3         143.3
# 7             전체근로자      농림어업 숙련 종사자(6)       17.4       137.2         132.5
# 8             전체근로자  기능원 및 관련 기능 종사자(7)       18.0       146.5         138.4
# 9             전체근로자  장치,기계조작 및 조립종사자(8)       20.5       173.7         152.9
# 10            전체근로자         단순노무 종사자(9)       17.9       139.3         132.0
# ...

# %%
df2
# Out:
#        시도별                직업별    2021  2021.1
# 0      시도별                직업별      남편      아내
# 1       전국                  계  101673  101673
# 2       전국                관리자    7379    2250
# 3       전국       전문가 및 관련 종사자   10851   10437
# 4       전국             사무 종사자   10129   11171
# ..     ...                ...     ...     ...
# 205  국   외    기능원 및 관련 기능 종사자      57      55
# 206  국   외  장치,기계 조작 및 조립 종사자      29      28
# 207  국   외           단순노무 종사자     148     188
# 208  국   외         무직, 가사, 학생     149     828
# 209  국   외            기타 및 미상     755    1327
#
# [210 rows x 4 columns]
